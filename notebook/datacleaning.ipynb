# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data

# %%
df = pd.read_csv(r"C:\Users\hamen\OneDrive\Desktop\project2\dataset\Zomato data .csv")
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    str
#  1   online_order                 148 non-null    str
#  2   book_table                   148 non-null    str
#  3   rate                         148 non-null    str
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    str
# dtypes: int64(2), str(5)
# memory usage: 8.2 KB

# %%
df.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
# fixed data in column rate
def handleRate(value):
 value = str(value).split('/')
 value = value[0];
 return float(value)

# %%
# change columns name
df["cost_of_two_customers"]=df["approx_cost(for two people)"]
df["listing_type"] = df["listed_in(type)"]
df = df.drop(columns=["approx_cost(for two people)"])
df = df.drop(columns=["listed_in(type)"])
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      cost_of_two_customers listing_type
# 0                      800       Buffet
# 1                      800       Buffet
# 2                      800       Buffet
# ...

# %%
sns.boxplot(data=df,x = df['votes'])
plt.show()

# %%
df['rate'] = df['rate'].apply(handleRate)

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    cost_of_two_customers listing_type
# 0                    800       Buffet
# 1                    800       Buffet
# 2                    800       Buffet
# 3                    300       Buffet
# 4                    600       Buffet

# %%
# we dont delete outlier data because there is some restaurants which have high number of customers and have votes

# %%
df.to_csv(r'C:\Users\hamen\OneDrive\Desktop\project2\dataset\zomato_clean_dataset.csv',index=False)
print("successfuly created")
# Out:
# successfuly created
