# %%
import pandas as pd

# %%
df = pd.read_csv(r"swiggy_raw_dataset.csv")
df.head()
# Out:
#    order_id  customer_id       city     restaurant       cuisine  \
# 0        40         1474     Mumbai  Biryani House  North Indian
# 1      1603         1936  Bangalore      Spice Hub  North Indian
# 2      3344         1252     Mumbai    Pizza World      Desserts
# 3      4549         1419     Mumbai  Biryani House      Desserts
# 4      3610         1630  Hyderabad    Urban Tadka           NaN
#
#    order_amount  delivery_time_mins  rating order_status payment_mode  \
# 0        709.13                  28     4.7      Pending       Wallet
# 1        938.23                  40     3.6      Pending       Wallet
# 2        470.62                  43     4.7    Cancelled          UPI
# 3       1448.17                  23     4.2      Pending       Wallet
# 4        567.30                  10     3.4    Delivered       Wallet
#
#    order_date
# 0  2024-01-04
# 1  2024-02-02
# 2  2024-01-17
# 3  2024-04-22
# 4  2024-09-05

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'city', 'restaurant', 'cuisine',
#        'order_amount', 'delivery_time_mins', 'rating', 'order_status',
#        'payment_mode', 'order_date'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            5250 non-null   int64
#  1   customer_id         5250 non-null   int64
#  2   city                4992 non-null   str
#  3   restaurant          4988 non-null   str
#  4   cuisine             4991 non-null   str
#  5   order_amount        5250 non-null   float64
#  6   delivery_time_mins  5250 non-null   int64
#  7   rating              4986 non-null   float64
#  8   order_status        5250 non-null   str
#  9   payment_mode        5250 non-null   str
#  10  order_date          5250 non-null   str
# dtypes: float64(2), int64(3), str(6)
# memory usage: 451.3 KB

# %%
df.describe()
# Out:
#           order_id  customer_id  order_amount  delivery_time_mins       rating
# count  5250.000000  5250.000000   5250.000000         5250.000000  4986.000000
# mean   2494.941143  1504.372381    794.791499           34.502857     3.028480
# std    1441.934066   290.877086    399.082584           14.328870     1.152456
# min       1.000000  1000.000000    100.170000           10.000000     1.000000
# 25%    1247.250000  1252.000000    449.470000           22.000000     2.000000
# 50%    2492.500000  1507.000000    792.295000           35.000000     3.000000
# 75%    3738.750000  1760.000000   1127.415000           47.000000     4.000000
# max    5000.000000  1999.000000   1499.850000           59.000000     5.000000

# %%
df.isnull().sum()
# Out:
# order_id                0
# customer_id             0
# city                  258
# restaurant            262
# cuisine               259
# order_amount            0
# delivery_time_mins      0
# rating                264
# order_status            0
# payment_mode            0
# order_date              0
# dtype: int64

# %%
df["order_id"].duplicated().sum()
# Out:
# np.int64(250)

# %%
df["city"].unique()
# Out:
# <StringArray>
# ['Mumbai', 'Bangalore', 'Hyderabad', 'Kolkata', 'Delhi', 'Chennai', nan]
# Length: 7, dtype: str

# %%
df["payment_mode"].unique()
# Out:
# <StringArray>
# ['Wallet', 'UPI', 'Card', 'Cash']
# Length: 4, dtype: str

# %%
df["cuisine"].unique()
# Out:
# <StringArray>
# ['North Indian',     'Desserts',            nan,      'Italian',
#  'South Indian',      'Chinese',    'Fast Food']
# Length: 7, dtype: str

# %%
df["restaurant"].unique()
# Out:
# <StringArray>
# ['Biryani House',     'Spice Hub',   'Pizza World',   'Urban Tadka',
#  'Foodies Point',     'Sushi Zen',             nan]
# Length: 7, dtype: str

# %%
df["order_status"].unique()
# Out:
# <StringArray>
# ['Pending', 'Cancelled', 'Delivered']
# Length: 3, dtype: str
